# %% [markdown]
# # Analysis of M74 (NGC 0628)
#
# Date: 22 April 2025
#
# This is the first data set that I am working on for my summer project.

# %%
from XRBID.Sources import NewSources, LoadSources
from XRBID.WriteScript import WriteReg

from astroquery.mast import Observations

import shutil
import glob
import os

# %% [markdown]
# # Converting X-ray data into DS9 format

# %%
# there's also this
TempSources = NewSources(infile="/Users/undergradstudent/Research/XRB-Analysis/Chandra/M74/M74_cscresults.vot", rename=True,
                        outfile="/Users/undergradstudent/Research/XRB-Analysis/Chandra/M74/M74_cscresults.frame")
# Out:
# Reading in table from /Users/undergradstudent/Research/XRB-Analysis/Chandra/M74_cscresults.vot
# Enter new header names, or hit 'Enter' to keep name.
# separation:  Separation
# name:  CSC ID
# ra:  RA
# dec:  Dec
# err_ellipse_r0:  Err Ellipse Major
# err_ellipse_r1:  Err Ellipse Minor
# err_ellipse_ang:  Err Ellipse Angle
# significance:  Significance
# likelihood_class:  Likelihood
# conf_flag:
# sat_src_flag:  Saturation
# streak_src_flag:  Streak
# flux_aper_b:  Flux
# flux_aper_lolim_b:  Flux lolim
# flux_aper_hilim_b:  Flux hilim
# flux_aper_w:
# flux_aper_lolim_w:
# flux_aper_hilim_w:
# flux_aper_avg_b:
# flux_aper_avg_lolim_b:
# flux_aper_avg_hilim_b:
# flux_aper_avg_w:
# flux_aper_avg_lolim_w:
# flux_aper_avg_hilim_w:
# hard_hs:  HM Ratio
# theta_mean:  Theta
# src_cnts_aper_b:  Counts
# src_cnts_aper_lolim_b:  Counts lolim
# src_cnts_aper_hilim_b:  Counts hilim
# Reading in sources from /Users/undergradstudent/Research/XRB-Analysis/Chandra/M74_cscresults.frame...
# DONE

# %%
# Will remove the index column 
TempSources = LoadSources("/Users/undergradstudent/Research/XRB-Analysis/Chandra/M74/M74_cscresults.frame")
display(TempSources)

sources = TempSources
outfile = "/Users/undergradstudent/Research/XRB-Analysis/Chandra/M74/M74_cscresults.reg"

# Write to a DS9-compatibel region file
WriteReg(TempSources, outfile=outfile, 
         idname="CSC ID", radius=50,
         width=2, color="hotpink",
         showlabel=True)
# Out:
# Reading in sources from /Users/undergradstudent/Research/XRB-Analysis/Chandra/M74/M74_cscresults.frame...
#      Separation                 CSC ID         RA        Dec  \
# 0      0.028833  2CXO J013641.7+154701  24.173953  15.783637
# 1      0.028833  2CXO J013641.7+154701  24.173953  15.783637
# 2      0.028833  2CXO J013641.7+154701  24.173953  15.783637
# 3      0.028833  2CXO J013641.7+154701  24.173953  15.783637
# 4      6.010518  2CXO J013641.4+154704  24.172598  15.784692
# ..          ...                    ...        ...        ...
# 487  359.140361  2CXO J013617.6+154830  24.073525  15.808442
# 488  359.140361  2CXO J013617.6+154830  24.073525  15.808442
# 489  359.140361  2CXO J013617.6+154830  24.073525  15.808442
# 490  359.140361  2CXO J013617.6+154830  24.073525  15.808442
# 491  359.714886  2CXO J013629.6+154146  24.123473  15.696325
#
#      Err Ellipse Major  Err Ellipse Minor  Err Ellipse Angle  Significance  \
# ...

# %% [markdown]
# # Mosaicking
#
# Now, I will working on creating Mosaics with the HST data. Since mosaicking uses a lot of memory, I will be using the command line to do this, however, I will be storing my code in this jupyter notebook for the ease of reproducibility.

# %% [markdown]
# ## Downloading HST Observations with astroquery

# %%
# %%time
print("Finding Observations for ACS/WFC images...")
obs_table = Observations.query_criteria(objectname="NGC0628", obs_collection="HST",
                                       filters=["F435W", "F555W", "F658N", "F814W", "F606W"],
                                        proposal_id=[10402, 9796, 15645, 13804, 11675],
                                       instrument_name="ACS/WFC")
print("Done")
# Out:
# Finding Observations for ACS/WFC images...
# Done
# CPU times: user 27.3 ms, sys: 6.74 ms, total: 34 ms
# Wall time: 46.1 s

# %%
pwd
# Out:
# '/Users/undergradstudent/Research/XRB-Analysis/HST/M74'

# %%
# %%time
print("Downloading data.\nThis may take several minutes...\n")
products = Observations.get_product_list(obs_table)
data_prod = ['DRC']
data_type = ['HAP-SVM']

Observations.download_products(products, project=data_type,
                               productSubGroupDescription=data_prod)
print("Done")
# Out:
# ...
# This may take several minutes...
#
# INFO: 101 of 190 products were duplicates. Only returning 89 unique product(s). [astroquery.mast.utils]
# ...
# Done
# CPU times: user 1min 35s, sys: 1min 33s, total: 3min 9s
# Wall time: 29min 54s

# %%
# Gather DRC files
input_drcs = glob.glob(os.path.join('mastDownload', 'HST', '*', '*.fits'))

# Move files from mastDownload directory in current directory
for drc in input_drcs:
    shutil.copy(drc, os.path.basename(drc))

shutil.rmtree('mastDownload') # remove the extra directories
print('Done')
# Out:
# Done

# %%
drc_files = glob.glob("hst*_acs_wfc_*_j*_drc.fits")
drc_files.sort()
print("Beginning")
count = 0
for i, f in enumerate(drc_files):
    try: 
        hdu = fits.open(f)
    except: print(f, "not good. Please remove.")
    count = count + 1
    print(count)

print("end")
# Out:
# Beginning
# hst_10402_21_acs_wfc_f435w_j96r21_drc.fits not good. Please remove.
# 1
# hst_10402_21_acs_wfc_f435w_j96r21j3_drc.fits not good. Please remove.
# 2
# hst_10402_21_acs_wfc_f435w_j96r21j4_drc.fits not good. Please remove.
# 3
# hst_10402_21_acs_wfc_f555w_j96r21_drc.fits not good. Please remove.
# 4
# hst_10402_21_acs_wfc_f555w_j96r21j6_drc.fits not good. Please remove.
# 5
# hst_10402_21_acs_wfc_f555w_j96r21j8_drc.fits not good. Please remove.
# 6
# hst_10402_21_acs_wfc_f658n_j96r21_drc.fits not good. Please remove.
# 7
# hst_10402_21_acs_wfc_f658n_j96r21ja_drc.fits not good. Please remove.
# 8
# hst_10402_21_acs_wfc_f658n_j96r21jc_drc.fits not good. Please remove.
# 9
# hst_10402_21_acs_wfc_f814w_j96r21_drc.fits not good. Please remove.
# 10
# hst_10402_21_acs_wfc_f814w_j96r21je_drc.fits not good. Please remove.
# 11
# hst_10402_21_acs_wfc_f814w_j96r21jg_drc.fits not good. Please remove.
# 12
# hst_10402_21_acs_wfc_total_j96r21_drc.fits not good. Please remove.
# 13
# ...

# %%
# downloading files 
obs_table = Observations.query_criteria(objectname="NGC 0628", obs_collection="HST", 
filters=["F435W", "F555W", "F658N", "F814W", "F606W"], 
proposal_id=[10402, 9796, 15645, 13804, 11675], instrument_name="ACS/WFC")

print("Downloading data.\n This may take several minutes... \n")
products = Observations.get_product_list(obs_table)
data_prod = ['FLC']       # other options are ['FLT','DRC','DRZ']
data_type = ['HAP-SVM']   # other options are ['CALACS','CALWF3','CALWP2']

Observations.download_products(products, project=data_type, 
                               productSubGroupDescription=data_prod)
print("Done")

input_flcs = glob.glob(os.path.join('mastDownload','HST','*','*.fits'))

# Moving files from mastDownload directory into current directory
for flc in input_flcs:
  shutil.copy(flc, os.path.basename(flc))


shutil.rmtree('mastDownload') # removes the extra directories
print("Done")


### Trying to create a good mosaic for M74 (NGC0629)

reffile = glob.glob("*j96r23*")[0]

tweakreg.TweakReg(flc_files, refimage=reffile, 
                  imagefindcfg={'threshold':100, 'conv_width':3.5},
                  expand_refcat=False, writecat=False, 
                  enforce_user_order=False, 
                  fitgeometry='rscale', # allows shift, rotation & rescale
                  minobj=3, sigma=3.0, nclip=3, 
                  searchrad=1.0, searchunits='arcseconds', 
                  peakmax=70000, ylimit=0.3, interactive=False, 
                  shiftfile=True, reusename=True, 
                  outshifts='NGC0628_shifts_acs_f555w.txt', 
                  updatehdr=False)
                  
from astropy.table import Table

shift_table = Table.read('NGC0628_shifts_acs_f555w.txt',
                         format='ascii.no_header',
                         names=['file', 'dx', 'dy', 'rot',
                                'scale', 'xrms', 'yrms'])
                                
formats = ['.2f', '.2f', '.3f', '.5f', '.2f', '.2f']
for i, col in enumerate(shift_table.colnames[1:]):
    shift_table[col].format = formats[i]
    

print(shift_table)

tweakreg.TweakReg(flc_files, refimage=reffile, 
                  imagefindcfg={'threshold':100, 'conv_width':3.5},
                  expand_refcat=False, writecat=False, 
                  enforce_user_order=False, 
                  fitgeometry='shift', # allows shift, rotation & rescale
                  minobj=3, sigma=3.0, nclip=3, 
                  searchrad=1.0, searchunits='arcseconds', 
                  peakmax=70000, ylimit=0.3, interactive=False, 
                  shiftfile=True, reusename=True, 
                  outshifts='NGC0628_shifts_acs_f555w.txt', 
                  updatehdr=True)
                  
from drizzlepac.astrodrizzle import AstroDrizzle as adriz

adriz(flc_files, output='NGC0628_mosaic_acs_f555w',
      preserve=False, clean=True, context=False,
      skymethod='match', # renormalizes the brightness of each field
      driz_sep_bits='4096', driz_cr_corr=True,
      final_bits='4096', final_wcs=True, final_rot=0,  # places North pointed up
      configobj=None, overwrite=True, build=False)
      
### At this point, I realized some of the fields may need a rotation. 
# Changing to fitgeometry="general" to see if this yields better results. 

tweakreg.TweakReg(flc_files, refimage=reffile, 
                  imagefindcfg={'threshold':150, 'conv_width':3.5},
                  expand_refcat=True, writecat=True, 
                  enforce_user_order=False, 
                  fitgeometry='general',
                  minobj=15, sigma=3.0, nclip=3, 
                  searchrad=2.0, searchunits='arcseconds', 
                  peakmax=70000, ylimit=0.3, interactive=False, 
                  shiftfile=True, reusename=True, 
                  outshifts='NGC0628_shifts_acs_f555w.txt', 
                  updatehdr=False)
                  
cat = 'hst_10402_23_acs_wfc_f555w_j96r23bb_flc_refxy_catalog.coo'

tweakreg.TweakReg(flc_files, refimage=reffile, 
                  imagefindcfg={'threshold':400, 'conv_width':3.5},
                  expand_refcat=True, writecat=True, 
                  enforce_user_order=False, 
                  fitgeometry='shift',
                  minobj=3, sigma=15.0, nclip=3, 
                  searchrad=1.0, searchunits='arcseconds', 
                  peakmax=70000, ylimit=0.3, interactive=False, 
                  shiftfile=True, reusename=True, 
                  outshifts='NGC0628_shifts_acs_f555w.txt', 
                  updatehdr=False)
# THIS WORKED! made the cumulative_sky*.coo catalog that I originally had in my guide.                  

shift_table = Table.read('NGC0628_shifts_acs_f555w.txt',
                         format='ascii.no_header',
                         names=['file', 'dx', 'dy', 'rot',
                                'scale', 'xrms', 'yrms'])
                                
formats = ['.2f', '.2f', '.3f', '.5f', '.2f', '.2f']
for i, col in enumerate(shift_table.colnames[1:]):
    shift_table[col].format = formats[i]
    

print(shift_table)

                 
# When creating a catalog with the images, it needs to be read in as catalog instead of refcat
cat = glob.glob('cumulative*')[0]
tweakreg.TweakReg(flc_files, refimage=reffile, 
                  imagefindcfg={'threshold':400, 'conv_width':3.5},
                  catalog=cat,
                  enforce_user_order=False, 
                  fitgeometry='shift',
                  minobj=3, sigma=15.0, nclip=3, 
                  searchrad=1.0, searchunits='arcseconds', 
                  peakmax=70000, ylimit=0.3, interactive=False, 
                  shiftfile=True, reusename=True, 
                  outshifts='NGC0628_shifts_acs_f555w.txt', 
                  updatehdr=True)
                  
# If using a catalog obtained elsewhere, read it in as refcat, not catalog
# Use refxcol/refycol to define the column index of the coordinates

cat = 'hst_10402_23_acs_wfc_f555w_j96r23_segment-cat.ecsv'
tweakreg.TweakReg(flc_files, refimage=reffile, 
                  imagefindcfg={'threshold':400, 'conv_width':3.5},
                  refcat=cat, refxcol=3, refycol=4, 
                  expand_refcat=False, 
                  enforce_user_order=False, 
                  fitgeometry='shift',
                  minobj=5, sigma=5.0, nclip=3, 
                  searchrad=1.0, searchunits='arcseconds', 
                  peakmax=70000, ylimit=0.3, interactive=False, 
                  shiftfile=True, reusename=True, 
                  outshifts='NGC0628_shifts_acs_f555w.txt', 
                  updatehdr=False)

tweakreg.TweakReg(flc_files, refimage=reffile, 
                  imagefindcfg={'threshold':400, 'conv_width':3.5},
                  refcat=cat, refxcol=3, refycol=4, 
                  expand_refcat=False, 
                  enforce_user_order=False, 
                  fitgeometry='shift',
                  minobj=5, sigma=5.0, nclip=3, 
                  searchrad=1.0, searchunits='arcseconds', 
                  peakmax=70000, ylimit=0.3, interactive=False, 
                  shiftfile=True, reusename=True, 
                  outshifts='NGC0628_shifts_acs_f555w.txt', 
                  updatehdr=True)

adriz(flc_files, output='NGC0628_mosaic_acs_f555w',
      preserve=False, clean=True, context=False,
      skymethod='match', # renormalizes the brightness of each field
      driz_sep_bits='4096', driz_cr_corr=True,
      final_bits='4096', final_wcs=True, final_rot=0,  # places North pointed up
      configobj=None, overwrite=True, build=False)
      
      
# Gettting closer. Need to try making the catalog based on the filter that's the blurriest? 

reffile='hst_10402_21_acs_wfc_f555w_j96r21j6_flc.fits'
tweakreg.TweakReg(flc_files, refimage=reffile, 
                  imagefindcfg={'threshold':150, 'conv_width':3.5},
                  expand_refcat=True, writecat=True, 
                  enforce_user_order=False, 
                  fitgeometry='shift',
                  minobj=3, sigma=5.0, nclip=3, 
                  searchrad=1.0, searchunits='arcseconds', 
                  peakmax=70000, ylimit=0.3, interactive=False, 
                  shiftfile=True, reusename=True, 
                  outshifts='NGC0628_shifts_acs_f555w.txt', 
                  updatehdr=False)                

shift_table = Table.read('NGC0628_shifts_acs_f555w.txt',
                         format='ascii.no_header',
                         names=['file', 'dx', 'dy', 'rot',
                                'scale', 'xrms', 'yrms'])
                                
formats = ['.2f', '.2f', '.3f', '.5f', '.2f', '.2f']
for i, col in enumerate(shift_table.colnames[1:]):
    shift_table[col].format = formats[i]
    

print(shift_table)

                 
# When creating a catalog with the images, it needs to be read in as catalog instead of refcat
cat = glob.glob('cumulative*')[0]
tweakreg.TweakReg(flc_files, refimage=reffile, 
                  imagefindcfg={'threshold':150, 'conv_width':3.5},
                  catalog=cat,
                  enforce_user_order=False, 
                  fitgeometry='shift',
                  minobj=3, sigma=5.0, nclip=3, 
                  searchrad=1.0, searchunits='arcseconds', 
                  peakmax=70000, ylimit=0.3, interactive=False, 
                  shiftfile=True, reusename=True, 
                  outshifts='NGC0628_shifts_acs_f555w.txt', 
                  updatehdr=True)
                  
adriz(flc_files, output='NGC0628_mosaic_acs_f555w',
      preserve=True, clean=True, context=False,
      skymethod='match', # renormalizes the brightness of each field
      driz_sep_bits='4096', driz_cr_corr=True,
      final_bits='4096', final_wcs=True, final_rot=0,  # places North pointed up
      configobj=None, overwrite=False, build=False)  
      
      
#### FINAL ANSWER ####
# Try AstroDrizzle first. Only if the alignment is wrong should one attempt tweakreg
# Make sure overwrite is set to false, as this apparently overwrites what's in the 
# OrIg_files folder. 

adriz(flc_files, output='testing_mosaic',
      preserve=True, clean=True, context=False,
      skymethod='globalmin+match', # renormalizes the brightness of each field
      #driz_sep_bits='4096', 
      driz_cr=True, driz_cr_corr=False, driz_cr_snr="20.0 18.0",
      #final_bits='4096', 
      final_wcs=True, final_rot=0,  # places North pointed up
      configobj=None, overwrite=False, build=False)        
# I'm changing my cosmic ray correction S/R settings because it appears some stars are being flagged as CRs 

# Red mosaic is misaligned
flc_files = glob.glob("*f814w*flc*.fits")
flc_files.sort()     
adriz(flc_files, output='testing_mosaic_f814w',
      preserve=True, clean=True, context=False,
      skymethod='globalmin+match', # renormalizes the brightness of each field
      driz_cr=True, driz_cr_corr=False, driz_cr_snr="20.0 18.0",
      final_wcs=True, final_rot=0,  # places North pointed up
      configobj=None, overwrite=False, build=False)      
      
flc_files = glob.glob("*f435w*flc*.fits")
flc_files.sort()     
adriz(flc_files, output='testing_mosaic_f435w',
      preserve=True, clean=True, context=False,
      skymethod='globalmin+match', # renormalizes the brightness of each field
      driz_cr=True, driz_cr_corr=False, #driz_cr_snr="20.0 18.0",
      final_wcs=True, final_rot=0,  # places North pointed up
      configobj=None, overwrite=False, build=False)      
              
# Now need to create a catalog from the green filter. 
# Save this, read it in to TweakReg from red. See if that helps red mosaic. 

# Attempting to align red to the green mosaic
# First need to make a catalog using the green mosaic
cat = 'NGC0628_f555w_sources.csv'
flc_files = glob.glob("*f814w*flc*.fits")
flc_files.sort()
reffile = "testing_mosaic_drc_sci.fits"
tweakreg.TweakReg(flc_files, refimage=reffile, 
                  imagefindcfg={'threshold':95, 'conv_width':3.5},
                  catalog=cat, refxcol=1, refycol=2, 
                  expand_refcat=False, 
                  enforce_user_order=False, 
                  fitgeometry='general',
                  minobj=3, sigma=2., nclip=3, 
                  searchrad=1.0, searchunits='arcseconds', 
                  peakmax=70000, ylimit=0.3, interactive=False, 
                  shiftfile=True, reusename=True, 
                  outshifts='NGC0628_shifts_acs_f814w.txt', 
                  updatehdr=False)


shift_table = Table.read('NGC0628_shifts_acs_f814w.txt',
                         format='ascii.no_header',
                         names=['file', 'dx', 'dy', 'rot',
                                'scale', 'xrms', 'yrms'])
                                
formats = ['.2f', '.2f', '.3f', '.5f', '.2f', '.2f']
for i, col in enumerate(shift_table.colnames[1:]):
    shift_table[col].format = formats[i]
    

print(shift_table)

adriz(flc_files, output='testing_mosaic_f814w',
      preserve=True, clean=True, context=False,
      skymethod='globalmin+match', # renormalizes the brightness of each field
      driz_cr=True, driz_cr_corr=False, driz_cr_snr="15.0 13.0",
      final_wcs=True, final_rot=0,  # places North pointed up
      configobj=None, overwrite=False, build=False)   
      
      
flc_files = glob.glob("*f435w*flc*.fits")
flc_files.sort()
tweakreg.TweakReg(flc_files, refimage=reffile, 
                  imagefindcfg={'threshold':100, 'conv_width':3.5},
                  catalog=cat, refxcol=1, refycol=2, 
                  expand_refcat=False, 
                  enforce_user_order=False, 
                  fitgeometry='general',
                  minobj=3, sigma=2.5, nclip=3, 
                  searchrad=1.0, searchunits='arcseconds', 
                  peakmax=70000, ylimit=0.3, interactive=False, 
                  shiftfile=True, reusename=True, 
                  outshifts='NGC0628_shifts_acs_f435w.txt', 
                  updatehdr=False)


shift_table = Table.read('NGC0628_shifts_acs_f435w.txt',
                         format='ascii.no_header',
                         names=['file', 'dx', 'dy', 'rot',
                                'scale', 'xrms', 'yrms'])
                                
formats = ['.2f', '.2f', '.3f', '.5f', '.2f', '.2f']
for i, col in enumerate(shift_table.colnames[1:]):
    shift_table[col].format = formats[i]
    

print(shift_table)

flc_files = glob.glob("*f435w*flc*.fits")
flc_files.sort()  
adriz(flc_files, output='testing_mosaic_f435w',
      preserve=True, clean=True, context=False,
      skymethod='globalmin+match', # renormalizes the brightness of each field
      driz_cr=True, driz_cr_corr=False, #driz_cr_snr="15.0 13.0",
      final_wcs=True, final_rot=0,  # places North pointed up
      configobj=None, overwrite=False, build=False)   
      
# Looks good. Going to rerun to see if green realigns to the rest of the mosaic
# as there's an offset of a few pixels. 

flc_files = glob.glob("*f555w*flc*.fits")
flc_files.sort()
tweakreg.TweakReg(flc_files, refimage=reffile, 
                  imagefindcfg={'threshold':100, 'conv_width':3.5},
                  catalog=cat, refxcol=1, refycol=2, 
                  expand_refcat=False, 
                  enforce_user_order=False, 
                  fitgeometry='general',
                  minobj=3, sigma=2.5, nclip=3, 
                  searchrad=1.0, searchunits='arcseconds', 
                  peakmax=70000, ylimit=0.3, interactive=False, 
                  shiftfile=True, reusename=True, 
                  outshifts='NGC0628_shifts_acs_f555w.txt', 
                  updatehdr=False)


shift_table = Table.read('NGC0628_shifts_acs_f555w.txt',
                         format='ascii.no_header',
                         names=['file', 'dx', 'dy', 'rot',
                                'scale', 'xrms', 'yrms'])
                                
formats = ['.2f', '.2f', '.3f', '.5f', '.2f', '.2f']
for i, col in enumerate(shift_table.colnames[1:]):
    shift_table[col].format = formats[i]
    

print(shift_table)

adriz(flc_files, output='testing_mosaic_f555w',
      preserve=True, clean=True, context=False,
      skymethod='globalmin+match', # renormalizes the brightness of each field
      driz_cr=True, driz_cr_corr=False, #driz_cr_snr="15.0 13.0",
      final_wcs=True, final_rot=0,  # places North pointed up
      configobj=None, overwrite=False, build=False)  
      
# That more or less fixed the offset!
